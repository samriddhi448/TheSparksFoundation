# %% [markdown]
# <a href="https://colab.research.google.com/github/samriddhi448/TheSparksFoundation/blob/main/NYTCovid_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NYTCovid class test
# ## Samriddhi Jain

# %%
from NYTCovid import NYTCovid

# %%
n = NYTCovid()

# %%
n.dateUpdate()
# Out:
# Data has not been updated even once!

# %%
n.updateState()

# %%
n.peek()
# Out:
# First 5 rows of the state data
# ==================================================
#         date       state  fips  cases  deaths
# 0 2020-01-21  Washington    53      1       0
# 1 2020-01-22  Washington    53      1       0
# 2 2020-01-23  Washington    53      1       0
# 3 2020-01-24    Illinois    17      1       0
# 4 2020-01-24  Washington    53      1       0

# %%
n.plot_state(state='California',last_30_days=True)
# Out:
# Data not processed yet. Cannot plot statewise.

# %%
n.process()
# Out:
# Processing...
# Finished. Took 0.186 seconds

# %%
n.plot_state(state='California',last_30_days=True)

# %%
n.plot_multi_state(states=['California', 'Michigan', 'Georgia','Illinois'],
                  last_30_days=True)

# %%
n.rankState(N=6)

# %%
n.rankState(N=4,daterank='2020-03-26')
